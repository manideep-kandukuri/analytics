# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Laliga.csv')
#data.rename(columns=data.iloc[0])
#data.head()
#data.drop(index=1,axis=1)

# %%
data = data.rename(columns=data.iloc[0])
data = data.drop(index=0)

# %%
data.head()
# Out:
#   Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp BestPosition
# ...

# %%
data.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
#I prefer to check the data using data.sample().It gives me random rows so that I can identify the nulls/symbols in data
#which are not present in head or tail of data

# %%
data.sample(10)
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 10  10           Real Betis      51   1884        1728      606        440
# 12  12           Celta Vigo      51   1789        1698      586        389
# 5    5      Athletic Bilbao      86   3368        2762     1209        633
# 18  18               Oviedo      38   1174        1192      408        292
# 47  47            Gimnastic       4     91         116       34         16
# 42  42           Pontevedra       6    150         180       53         44
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# 27  27             Tenerife      13    510         494      155        128
# 50  50             Alcoyano       4     76         108       30         16
# 40  40           Recreativo       5    188         186       50         46
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# # Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
data = data.replace('-',0)

# %%
data.sample(10)
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 43  43             Numancia       4    148         152       37         37
# 10  10           Real Betis      51   1884        1728      606        440
# 50  50             Alcoyano       4     76         108       30         16
# 31  31            Salamanca      12    375         423      123        102
# 14  14     Racing Santander      44   1416        1428      453        336
# 32  32             Sabadell      14    353         426      129         95
# 30  30              Levante      11    416         402      113         95
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# 20  20           Las Palmas      33   1020        1096      367        242
# 56  56              Leganes       1     35          38        8         11
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# # Print all the teams which have started playing between 1930-1980. (5 points)

# %%
data['Debut'] = data['Debut'].str[0:4]

# %%
data['Debut'] = data['Debut'].astype('int32')
data.head()
# Out:
#   Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
#     T  Debut Since/LastApp BestPosition
# ...

# %%
data[(data['Debut'] >= 1930) & (data['Debut'] <=1980)]['Team'].unique()
# Out:
# array(['Valencia', 'Sevilla', 'Zaragoza', 'Real Betis',
#        'Deportivo La Coruna', 'Celta Vigo', 'Valladolid',
#        'Sporting Gijon', 'Osasuna', 'Malaga', 'Oviedo', 'Mallorca',
#        'Las Palmas', 'Granada', 'Rayo Vallecano', 'Elche', 'Hercules',
#        'Tenerife', 'Murcia', 'Alaves', 'Levante', 'Salamanca', 'Sabadell',
#        'Cadiz', 'Castellon', 'Cordoba', 'Recreativo', 'Burgos CF',
#        'Pontevedra', 'Gimnastic', 'Alcoyano', 'Jaen', 'AD Almeria',
#        'Lleida', 'Condal', 'Atletico Tetuan', 'Cultural Leonesa'],
#       dtype=object)

# %% [markdown]
# # Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
 data['Points']=data['Points'].astype('int32')

# %%
data["Rank"] = data["Points"].rank(ascending=False,method ='dense')

# %%
data[data['Rank']<=5]
# Out:
#   Pos             Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86    4385        2762     1647        552
# 2   2        Barcelona      86    4262        2762     1581        573
# 3   3  Atletico Madrid      80    3442        2614     1241        598
# 4   4         Valencia      82    3386        2664     1187        616
# 5   5  Athletic Bilbao      86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth   T  \
# 1       563     5947         3140  ...        23     8      8     3     4  79
# 2       608     5900         3114  ...        25    12     12     4     6  83
# 3       775     4534         3309  ...         8    16      9     7     6  56
# 4       861     4398         3469  ...         6    10     11    10     7  50
# 5       920     4631         3700  ...         7    10      5     8    10  49
#
#   Debut  Since/LastApp BestPosition Rank
# ...

# %% [markdown]
# # Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
# #Goal_diff_count = GoalsFor - GoalsAgainst

# %%
def Goal_diff_count():   
    data['Goal_diff_count'] = data['GoalsFor'].astype(int)-data['GoalsAgainst'].astype(int)
    print(data[['Team','Goal_diff_count']].sort_values(by = 'Goal_diff_count',ascending=False))
    print('\nTeam with Max Goals:\n',data[data['Goal_diff_count']==data['Goal_diff_count'].max()][['Team','Goal_diff_count']])
    print('\nTeam with Min Goals:\n',data[data['Goal_diff_count']==data['Goal_diff_count'].min()][['Team','Goal_diff_count']])

    #we get a negative count for team with min goal diff because the golas against are higher than goals for.
    #we can use abs function also to get rid of negative numbers
    
Goal_diff_count()
# Out:
#                 Team  Goal_diff_count
# 1        Real Madrid             2807
# 2          Barcelona             2786
# 3    Atletico Madrid             1225
# 5    Athletic Bilbao              931
# 4           Valencia              929
# ..               ...              ...
# 28            Murcia             -385
# 20        Las Palmas             -399
# 15    Sporting Gijon             -399
# 13        Valladolid             -413
# 14  Racing Santander             -525
#
# [61 rows x 2 columns]
#
# Team with Max Goals:
#            Team  Goal_diff_count
# 1  Real Madrid             2807
#
# Team with Min Goals:
#                  Team  Goal_diff_count
# 14  Racing Santander             -525

# %% [markdown]
# # Create a new column with name “Winning Percent” and append it to the data set
#
# Percentage of Winning = (GamesWon / GamesPlayed)*100

# %%
data['Winning_Percent'] = (data['GamesWon'].astype(int)/data['GamesPlayed'].astype(int))*100

# %%
data.sample(10)
# Out:
#    Pos        Team Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# 12  12  Celta Vigo      51    1789        1698      586        389       723
# 51  51        Jaen       3      71          90       29         13        48
# 42  42  Pontevedra       6     150         180       53         44        83
# 34  34    Logrones       9     293         346       96         92       158
# 44  44       Eibar       3     132         114       35         27        52
# 52  52  Real Union       4      56          72       21         14        37
# 29  29      Alaves      12     421         380      125         81       174
# 50  50    Alcoyano       4      76         108       30         16        62
# 24  24       Elche      21     606         678      203        180       295
# 10  10  Real Betis      51    1884        1728      606        440       682
#
#    GoalsFor GoalsAgainst  ... Fourth Fifth Sixth   T Debut Since/LastApp  \
# ...

# %% [markdown]
# # Group teams based on their “Best position” and print the sum of their points for all positions

# %%
data.groupby('BestPosition')['Points'].sum().sort_values(ascending=False)
# Out:
# BestPosition
# 1     27933
# 2      6904
# 4      6563
# 3      5221
# 6      2113
# 5      1884
# 7      1186
# 8      1134
# 12      511
# 10      450
# 11      445
# 17      266
# 9        96
# 16       81
# 19       81
# 14       71
# 20       34
# 15       14
# Name: Points, dtype: int32
